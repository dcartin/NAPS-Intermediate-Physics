# %% [markdown]
# # Objectives
#
# * State Kepler's three laws of planetary motion.
# * Identify the conserved quantity associated with Kepler's 2nd law.
# * Calculate the orbital speed necessary for a small object to orbit another mass at a given radius.

# %% [markdown]
# # Kepler's 1st and 2nd laws
#
# ## Brief history of Kepler's laws
#
# ![Nicolaus Copernicus ([source](https://commons.wikimedia.org/wiki/File:Nikolaus_Kopernikus.jpg))](../img/Nikolaus_Kopernikus.png)
#
# Using measurements by Greek and Arab astronomers, Nicolaus Copernicus develops a model of the Solar System with the Sun at the center; this is published just before his death in 1543.
#
# ![Tycho Brahe ([source](https://commons.wikimedia.org/wiki/File:Tycho_Brahe.JPG))](../img/Tycho_Brahe.png)
#
# Inspired by earlier observatories in Baghdad and Istanbul, the Danish nobleman Tycho Brahe built in 1576 a large observatory on the island of Hven (now part of Sweden). He develops his own Solar System model, with all the planets orbiting the Sun, and the Sun orbiting the Earth.
#
# ![Johannes Kepler ([source](https://commons.wikimedia.org/wiki/File:Johannes_Kepler_1610.jpg#/media/File:Johannes_Kepler_1610.jpg))](../img/Johannes_Kepler.png)
#
# Using Brahe's observations of Mars, Johannes Kepler tries to fit the planet's orbit into the Copernican framework. When he realizes that the orbit is actually an ellipse, not a circle, he is able to formulate his three laws of planetary motion in the early decades of the 17th century.
#
# ## Kepler's first law of planetary motion
#
# You might have an image of the Earth and all the other planets moving in circular orbits, with the Sun sitting at the center. This is actually a fairly good picture -- the Earth's orbit around the Sun, for example, is very close to that of a circle. However, if you start taking accurate measurements, you will eventually see that the orbits of the planets are not exactly circular. This was the first key fact that Kepler discovered, and is encoded in his first law of planetary motion.
#
# > Planets move along elliptical orbits, with the Sun at one focus of the ellipse.
#
# So what does this mean exactly? First, the orbits are ellipses, rather than circles. You can think of an ellipse as a circle that has been "squashed" in one direction, so it is bigger in one direction than it is in the perpendicular direction. Although there is still a central point after this squashing, it turns out there are two special points called *focal points* or *foci* (the plural of *focus*).
#
# The following video does a good job of not only showing you how to draw an ellipse using the foci and a piece of string, but it also shows the meaning of the term *major axis* for the ellipse.

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('Et3OdzEGX_w', width = 600, height = 400, mute = 1)

# %% [markdown]
# You can see a simulation of the Earth's motion around the Sun by running the next cell. First, select "Model" to see a simplified version of the Earth-Sun system. If you then click on the checkboxes for "Path" and "Grid", and then press the play button, you can see what the Earth's orbit looks like. The Sun is placed at a grid intersection at the center of the screen. What do you notice about the orbital path of the Earth on the left and right sides? Do these points the same distance away from the Sun?

# %%
from IPython.display import IFrame

IFrame(src="https://phet.colorado.edu/sims/html/gravity-and-orbits/latest/gravity-and-orbits_en.html", width="600", height="400")
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://phet.colorado.edu/sims/html/gravity-and-orbits/latest/gravity-and-orbits_en.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# The figure below gives an exaggerated version of the Earth's orbit. The Sun is at one focus of the ellipse.
#
# ![Definition of the semi-major axis of an ellipse](../img/INT_AY20_MP2_L31_Fig01-Semi-major_axis_def_small.png)
#
# You can see that this ellipse is drawn so that it is wider in the left-right direction than it is in the up-down direction. The distance from the left side to the right is known as the *major axis*. However, more important for our purposes will be half of this distance, known as the *semi-major axis*. The semi-major axis is denoted by the symbol $a$, so the major axis shown in the figure is twice that, or $2a$. Think about what would happen if the ellipse became more circular -- the semi-major axis would be exactly the same as the radius of the circle! So, for a lot of things we talk about below, the semi-major axis $a$ will replace the radius of a circle that we usually use. We will see this in more detail in the next section.
#
# ## Kepler's second law of planetary motion
#
# When Kepler wrote down his laws, he described the secon law in the following form.
#
# > A line joining a planet and the Sun sweeps out equal areas during equal intervals of time.
#
# This is perhaps a strange way to put it from our perspective, but it reflects the more geometric framing for physical laws at that time. A pictorial representation of the basic idea is in the figure below.
#
# (ANIMATION?)
#
# Again, we have a planet moving in an elliptical orbit around the Sun (based on the first law). Suppose we divide the period of the planet's orbit -- which would be one year for the Earth -- into twelve "months", and draw a line between the planet and the Sun at the beginning of each month. Then Kepler's 2nd law says that the area of each of these wedges is exactly the same. So what does this mean? Since the planet is closest to the Sun on the right-hand side, the wedge is not so long in the left-right direction. On the left side, when the planet is furthest away from the Sun, it has the longest wedge. For these two areas to be the same in the same amount of time, on the right-hand side, the planet has to be traveling the fastest, while on the left-hand side, it must be traveling at its slowest.
#
# It turns out we can express the second law of planetary motion in a more modern viewpoint, using a concept we recently covered.
#
# > The angular momentum of the planet during its orbit around the Sun is conserved.
#
# To show this is the same as Kepler's statement, we need to review some facts first. Remember from Lesson LESSON LINK that the angular momentum of a point mass around an origin ${\vec r} = 0$ can be written as
#
# $$
#     {\vec L} = {\vec r} \times {\vec p}
# $$
#
# Suppose you consider a simplified system of a planet $P$ in orbit around the Sun $S$. Then the angular momentum of planet $P$ moving with velocity component $v_{\perp}$ perpendicular to the radius vector ${\vec r}$ has magnitude
#
# $$
# 	L_P = rmv_\perp
# $$
#
# Note that $v_\perp$ is not the magnitude of the velocity, but it is just the component of the velocity in the direction perpendicular to the radial vector ${\vec r}$, pointing towards the Sun. You can see how the velocity ${\vec v}$ is broken into its perpendicular and radial (along ${\vec r}$) components in the figure.
#
# ![The radial and perpendicular components of the planet's velocity ${\vec v}$](../img/QID-4546102-vel-vec-diag_small.png)
#
# The gravitational force ${\vec F}_{SP}$ on the planet points towards the Sun; the position vector ${\vec r}_P$ of the planet also points towards the Sun.
#
# ![Force and radial vectors for planet moving around the Sun](../img/INT_AY20_MP2_L30_Fig01-Orbiting_object_and_vectors_small.png)
#
# Because of this, the net torque on the planet ${\vec \tau} = {\vec r}_P \times {\vec F}_{SP} = 0$ since the two vectors are parallel. Since the net torque is zero, the angular momentum $L_P$ of the planet as it orbits the Sun is conserved. Now let's use this fact to show that conservation of angular momentum gives us Kepler's second law of planetary motion. This says that the area $\Delta A$ swept out by a line from the planet $P$ to the Sun $S$ is the same for every time period $\Delta t$. So, for a small time $\Delta t$, the area is really close to a triangle, as you can see from the diagram below.
#
# (NEED A FIGURE)
#
# The angle $\Delta \theta$ is the angular displacement of the planet seen by an observer on the Sun. From what we learned in rotational kinematics, this change in angle for a planet at distance $r$ gives an *arc length* traveled of $r \Delta \theta$. So the area of the triangle is
#
# $$
#     \Delta A = \frac{1}{2} (r)(r \Delta \theta)
# $$
#
# If you divide both sides by $\Delta t$, then the "areal velocity" $\Delta A / \Delta t$ is given by
#
# $$
#     \frac{\Delta A}{\Delta t} = \frac{1}{2} r^2 \frac{\Delta \theta}{\Delta t} = \frac{1}{2} r^2 \omega
# $$
#
# where $\omega$ is the angular speed of the planet. But since the moment of inertia $I$ of the planet around the Sun is $mr^2$, then
#
# $$
#     \frac{\Delta A}{\Delta t} = \frac{mr^2 \omega}{2m} = \frac{L_P}{2m}
# $$
#
# Thus, a constant angular momentum $L_P$ is the same as a constant area velocity.
#
# > **Problem:** Halley's comet is a famous object that comes close to the Sun about every 76 years; it will return to the inner solar system in the year 2061. The comet's *perihelion* (closest distance to the Sun) is 0.586 AU, where 1 AU is the mean distance from the Earth to the Sun. Its *aphelion* (furthest distance from the Sun) is 35.1 AU. If its speed at perihelion is 55.0 km/s, how fast is it moving (in m/s) at aphelion? This will be in late 2023, so it will happen soon!
#
# ![Halley's comet during its last visit to the inner Solar System in 1986 ([source](https://commons.wikimedia.org/wiki/File:Lspn_comet_halley.jpg))](../img/Lspn_comet_halley.png)
#
# > **Problem:** A *Hohmann transfer orbit* is the minimum energy orbit for a spacecraft to move from one orbital to another around the Sun. This would be used for a  space probe travelling from Earth to Venus, for example, with orbital radii of 1.00 AU and 0.723 AU, respectively. Suppose a spacecraft is moving at 27.3 km/s at the same distance from the Sun as the Earth and is in such a transfer orbit. Once it reaches the orbit of Venus, what will its orbital speed be (in km/s)?
#
# ![Hohmann transfer orbit between Earth and Venus](../img/INT_AY20_MP2_L30_Fig02-Transfer_orbit_small.png)

# %% [markdown]
# # Kepler's third law of planetary motion
#
# ## Orbital speed
#
# > **Problem:** For the values of the (essentially) circular orbits below, find the orbital speed of each satellite. **Hint:** You do not need the mass of Jupiter for this problem! We will use this information later to *find* Jupiter's mass
#
# | Image                    | Name     | Period $T$ (days) | Orbital radius $R$ (km) | Orbital speed $v_t$ (km/s) |
# |--------------------------|----------|-------------------|-------------------------|----------------------------|
# | ![](../img/Io.png)       | Io       | 1.77              | 421,800                 |                            |
# | ![](../img/Europa.png)   | Europa   | 3.55              | 671,100                 |                            |
# | ![](../img/Ganymede.png) | Ganymede | 7.16              | 1,070,400               |                            |
# | ![](../img/Callisto.png) | Callisto | 16.7              | 1,882,700               |                            |
#
#
# Image sources: [Io](https://commons.wikimedia.org/wiki/File:Io_highest_resolution_true_color.jpg), [Europa](https://commons.wikimedia.org/wiki/File:Europa-moon-with-margins.jpg), [Ganymede](https://commons.wikimedia.org/wiki/File:Moon_Ganymede_by_NOAA.jpg), [Callisto](https://commons.wikimedia.org/wiki/File:Callisto.jpg)
#
# What provides the centripetal force for each of these satellites? It is the gravitational force between Jupiter and the satellite. Setting the magnitudes of these forces to be equal,
#
# $$
# 	F_{grav} = F_{cp} \Rightarrow \frac{GM m}{R^2} = \frac{m v_{orb} ^2}{R}
# $$
#
# we can solve for the magnitude of the orbital speed of each satellite. Here $M$ is the mass of the primary object (e.g. Jupiter) and $m$ the mass of the secondary (e.g. one of the satellites). This gives us
#
# $$
#     v_{orb} = \sqrt{\frac{G M}{R}}
# $$
#
# > **Problem:** Using this relation and using the data from the table, find the mass of Jupiter.
#
# Note that the orbital speed decreases as the radius of the orbit increases. So Callisto has a smaller orbital speed than Io. In fact, since the semi-major axis of Callisto is about four times bigger than that of Io, its speed is close to half that of Io's. This relation also works for the planets around the Sun: Mercury has the fastest orbital speed of the eight planets, while Neptune has the smallest.
#
# ## Kepler's third law
#
# When solving the next problem algebraically, you will find the relationship between the period of an orbiting body, and the semi-major axis of its orbit, which is known as Kepler's 3rd law.
#
# > **Problem:** The planet Mars rotates once about its axis in 24 hours and 40 minutes; if Mars has a mass of $6.39 \times 10^{23}$ kg, how far would a space probe have to be from the center of Mars in order to have the same rotational period?
#
# ![The planet Mars ([source](https://commons.wikimedia.org/wiki/File:Mars_Valles_Marineris.jpeg))](../img/Mars.png)
#
# Using the algebraic expression derived in the last problem, we have the equation
#
# $$
# 	T^2 = \biggl( \frac{4 \pi^2}{GM} \biggr) a^3
# $$
#
# Here, $T$ is the period to complete one orbit around the mass $M$, and $a$ is the *semi-major* axis of the orbit. So far, we have assumed that the orbits are circular (so $a$ would be the radius $r$ of the circle). However, if the orbit is elliptical, then the distance measurement used is half the longest distance of the ellipse.
#
# ![Definition of the semi-major axis of an ellipse](../img/INT_AY20_MP2_L31_Fig01-Semi-major_axis_def_small.png)
#
# (YOU USE THIS PICTURE TWICE; REFER BACK TO IT SECOND TIME IN LATEX)
#
# Thus, **Kepler's third law** states that
#
# > The square of the orbital period of a planet is directly proportional to the cube of the semi-major axis of its orbit.
#
# > **Problem:** Mercury is the planet nearest to the Sun and has a rather eccentric orbit -- meaning there is a sizeable difference between its closest and furthest distances away from the Sun.
# >
# > 1. Suppose Mercury takes 0.241 yr to go once around the Sun. What is its semi-major axis in AU? Remember that the Earth's orbit has a semi-major axis of 1 AU and a period of 1.00 yr.
# > 1. If its aphelion from the Sun is 0.467 AU, what is the distance of its perihelion, in AU?
# > 1. 1 AU is about 149.6 million kilometers. Use this to find the mass of the Sun in kg.
#
# ![The planet Mercury ([source](https://commons.wikimedia.org/wiki/File:Mercury_in_color_-_Prockter07-edit1.jpg))](../img/Mercury.png)
#
# > **Problem:** In LESSON LINK, you worked through a problem involving a Hohmann transfer orbit, an orbit that takes you from one (roughly circular) orbit to another. In particular, the transfer was between the orbit of Earth (1.00 AU) to that of Venus (0.723 AU). If you were traveling along this orbit from Earth to Venus, how long would it take (in yr) for you to reach Venus? **Hint:** How far along the orbit have you traveled?
#
# ![Hohmann transfer orbit between Earth and Venus](../img/INT_AY20_MP2_L30_Fig02-Transfer_orbit_small.png)
#
# (YOU USE THIS PICTURE TWICE; REFER BACK TO IT SECOND TIME IN LATEX)

# %% [markdown]
# # Mission to Mars
#
# ## Overview
#
# You will now calculate some of the parameters for a manned mission to Mars, using many of the physics concepts you have learned this trimester, and uses these to construct a simulation for such a mission. First, you will construct a system which includes the Sun, the Earth and Mars; the planets will be placed in circular orbits due to the Sun's gravitational force. Then you will add in a rocket starting at the Earth that travels to Mars along a transfer orbit. Onward to the Red Planet!
#
# Important information to use for this notebook:
#
# <table>
# <tr>
#     <td>mass of Sun $M_{Sun}$</td>
#     <td width = "150px">$1.989 \times 10^{30}$ kg</td>
# </tr>
# <tr>
#     <td>semi-major axis $a_{Earth}$ of Earth</td>
#     <td>$1.496 \times 10^8$ km</td>
# </tr>
# <tr>
#     <td>semi-major axis $a_{Mars}$ of Mars</td>
#     <td>$2.279 \times 10^8$ km</td>
# </tr>
# </table>
#
# Assume that the Earth and Mars both travel around the Sun in perfect circles. Find the orbital speed (in km/s) of Earth and Mars.
#
# Recall from LESSON LINK that a Hohmann transfer orbit is a minimum energy orbit that allows you to go from one planet to another with the least amount of energy. For the Earth and Mars, the situation would be something like that shown in the figure below -- the transfer orbit is the dotted line.
#
# ![Transfer orbit between Earth and Mars](../img/INT_AY20_MP2_L32_Fig01-Earth_Mars_transfer_orbit_small.png)
#
# The semi-major axis of the transfer orbit is the average of the orbital radii for the Earth and Mars. Use this to figure out the time (in days) to complete *one-half* of the transfer orbit. This would be the time it takes to travel from the Earth to Mars along this orbit.
#
# A spacecraft traveling along the Hohmann transfer orbit obeys conservation of angular momentum (from Kepler's second law) and conservation of energy (if the spacecraft engine is turned off during the orbit). This gives you two equations for the spacecraft in terms of its speed $v_i$ at the Earth's orbit and its speed $v_f$ at Mars' orbit. Solve these two equations using the techniques of simultaneous equations for the two speeds $v_i$ and $v_f$ (in km/s).
#
# The speeds you found in the previous two problems are not the same as those of the planets Earth and Mars themselves, which you found earlier. Suppose you plan on using a 120. metric ton spacecraft (1 metric ton is 1000 kg) for a mission from Earth to Mars, using the Hohmann transfer orbit. Figure out the required amount of kinetic energy (in J) needed to speed up the spacecraft from Earth orbit into the transfer orbit. For comparison, the first stage of the Saturn V rocket used to send men to the Moon released a total of about 7.19 trillion joules.
#
# Using the same spacecraft as the last problem, find the additional amount of kinetic energy (in J) needed to speed up the spacecraft from the transfer orbit into Mars orbit.
#
# A launch opportunity for this type of mission opens up whenever Earth and Mars are in the same positions relative to each other. For example, the rocket must be at its furthest point from the Sun at the same time that Mars is at the same location. The two planets will have the same location relative to each other once every *synodic period* (remember you calculated this in LESSON LINK). How often (in years) will Earth and Mars be in the same location in their orbits relative to each other? **Hint:** Figure out the angular speed of both Earth and Mars -- the synodic period will be the time it takes for the difference in angular displacements of the two planets around the Sun to increase by $2 \pi$ radians.
#
# **Challenge:** To put it all together, figure out the total time (from Earth launch to Earth return, in years) it would take for the following mission to be executed:
#
# 1. Leave Earth orbit and travel along one-half of a Hohmann transfer orbit to Mars orbit (launch to arrival)
# 1. Stay on Mars until the two planets have orbited around the Sun enough so that Earth and Mars are in the correct positions for the return journey (you need to calculate this time to get your final answer!)
# 1. Leave Mars orbit and travel along one-half of a Hohmann transfer orbit to Earth orbit; this will be the same time as before, although the orbit has shifted (departure to return)
#
# In other words, the process would look something like the figures below. Note that the planets orbit counter-clockwise in this perspective.
#
# ![From Earth to Mars and back](../img/INT_AY20_MP2_L32_Fig02-Earth_Mars_total_trip.png)

# %% [markdown]
# ## Overview
#
# In this notebook, you will construct a simulation based on the Lesson LESSON LINK (MISSION TO MARS -- SEE ABOVE) worksheet you completed about a mission to Mars. First, you will construct a system which includes the Sun, the Earth and Mars; the planets will be placed in circular orbits due to the Sun's gravitational force. Then you will add in a rocket starting at the Earth that travels to Mars along a transfer orbit.
#
# ## Set-up
#
# Most of these modules are not new. The exceptions are <b>local_light</b>, which is needed to make the Sun actually glow, and <b>pi</b>, which gives the exact value of the mathematical constant $\pi$.

# %%
from vpython import canvas, color, cos, local_light, mag, norm, pi, \
    rate, sin, sphere, sqrt, textures, vector

# %% [markdown]
# ## Scaling physical quantities
#
# Up to this point, we have assumed that all the numbers used in our vPython simulations are in SI units. For example, if `ball.velocity = vector(2, 0, 0)`, then we would say that the object `ball` is moving to the right at 2 m/s. However, this would cause problems when trying to simulate the Solar System -- your computer may have an issue when the orbital radius of the Earth around the Sun is $1.496 \times 10^{11}$ meters!
#
# To get around this problem, we are going to scale the problem using a different set of units. As a warm-up for this, remember that instead of meters and seconds, we can use years and AU (astronomical units) for the periods and radii of the planetary orbits. For example, the Earth has a semi-major axis $a$ of 1.00 AU and a period $T$ of 1.00 year to go once around its orbit. Thus, using Kepler's third law equation,
#
# $$
#     T^2 = \biggl( \frac{4 \pi^2}{GM_{Sun}} \biggr) a^3
# $$
#
# this means that the constant value $GM_{Sun} = 4 \pi^2$ AU$^3$ / yr$^2$.
#
# **Problem:** Check that this is actually true by converting $GM_{Sun}$ from SI units (m and s) into AU and years. The mass of the Sun is $1.99 \times 10^{30}$ kg.
#
# This is close to what we want, but not perfect for simulating the motions of Earth and Mars. So, we will use a special unit of distance -- the "Python AU" or "PAU" -- and define 1.00 AU = 3.00 PAU. This means that in your simulation, the Earth will travel along a circular orbit of 3.00 PAU. Along with this, you will use the unit of time "Pyr" or "Python year". We will choose the value of $GM_{Sun}$ to be
#
# $$
#     GM_{Sun} = \frac{4 \pi^2}{3^3} \text{ PAU}^3 / \text{ Pyr}^2 = \frac{4 \pi^2}{27} \text{ PAU}^3 / \text{ Pyr}^2
# $$
#
# **Problem:** What is the period of the Earth in Pyr?
#
# Once we have this set of units, it is easy to find the radius of Mars' orbit. Since $a_{Mars}$ is 1.524 AU, then it is $1.524 \times 3$ or 4.572 PAU.
#
# **Problem:** What is the period of Mars in Pyr?
#
# Using the conversion factors outlined above, we can switch back and forth between the units used in this vPython simulation and the real world.
#
# ## Creating the Sun, Earth and Mars
#
# The first step for our simulation will be to create the Sun, as well as the Earth and Mars in orbit around it. The code below
#
# Make the following additions to your code before you run it:
#
# 1. Use the equation for the orbital speed of an object in a circular motion to define `V_EARTH` and `V_MARS` (both in PAU / Pyr). Although you can type in the actual number, you can also use the pre-defined values `R_EARTH`, `R_MARS` and `GM_SUN` along with the appropriate equation to have the computer calculate the speeds for you.
# 1. Define `MAX_TIME` as the length of the Earth's orbital period in Pyr. Again, you can have the computer calculate the exact value, if you wish.
# 1. Earlier, you defined the speeds `V_EARTH` and `V_MARS`, and the starting positions `Earth.pos` and `Mars.pos` are already given. Use this information to properly define the initial velocities `Earth.velocity` and `Mars.velocity` above the `while` loop. Remember that these velocites should be perpendicular to the position vectors for the Earth and Mars. In addition, make sure your planets travel in a counter-clockwise direction!
# 1. Finally, the most important part is to add the gravitational acceleration of the two planets. Remember that the *acceleration* ${\vec g}$ (rather than the *force*) on an object at a position ${\vec r}$ from a mass $M$ is given by
#     $$
#         {\vec g} = - \frac{GM}{r^2} {\hat r}
#     $$
#     where ${\hat r}$ is the unit vector in the same direction as the position vector ${\vec r}$. You can calculate the unit vector for a Python vector `r` by using `norm(r)`, and the magnitude of `r` using `mag(r)`. The position vector for the two planets will be their distance away from the Sun; however, the Sun is located at the origin, so you will only need to use the vectors `Earth.pos` and `Mars.pos`.
#
# Make all the additions in the code listed above, and then run the cell. If everything is correct, you should see the Earth and Mars traveling around the Sun in circular orbits in the time it takes for the Earth to go around once. Verify that this is true, or work on your code until everything works properly.

# %%
scene = canvas()
#scene.lights = []              # Makes the Sun the only light source

# Constant definitions

R_EARTH = 3                     # in PAU
R_MARS = 1.524 * R_EARTH        # in PAU
GM_SUN = (4 / 27) * pi ** 2     # in PAU^3 / Pyr^2

# Linear speed of objects

V_EARTH = #####
V_MARS = #####

# Starting angles for planets

Q_Earth = 0
Q_Mars = pi / 2

# Time definitions

MAX_TIME = #####
t = 0
dt = 0.01

# Create Sun as a glowing sphere

Sun = sphere(pos = vector(0, 0, 0), radius = 0.3, color = color.yellow, \
             emissive = True)
lamp = local_light(pos = Sun.pos, color = Sun.color)

# Create planets

Earth = sphere(pos = R_EARTH * vector(cos(Q_Earth), sin(Q_Earth), 0), \
               radius = 0.1, texture = textures.earth, make_trail = True)
Mars = sphere(pos = R_MARS * vector(cos(Q_Mars), sin(Q_Mars), 0), \
              radius = 0.1, color = color.red, make_trail = True)

# Define initial planetary velocities

Earth.velocity = #####
Mars.velocity = #####

###############################################
# Create rocket
#
###############################################

# If desired, set the camera to follow a specific object

scene.camera.follow(Earth)

# Evolution loop

while t < MAX_TIME:
    rate(100)
    
    # Update Earth position, velocity
    # Add the gravitational acceleration of the Earth
    
    Earth.velocity = Earth.velocity             
    Earth.pos = Earth.pos + Earth.velocity * dt
    
    # Update Mars position, velocity
    # Add the gravitational acceleration of Mars
    
    Mars.velocity = Mars.velocity               
    Mars.pos = Mars.pos + Mars.velocity * dt

    ###############################################
    # Update rocket position, velocity
    #
    ###############################################
    
    # Update time
    
    t = t + dt

# %% [markdown]
# ## What is not included here
#
# In the cell above, the Earth is only affected by the gravitational force from the Sun, and the same for Mars. This means there are several forces missing: the force between the Earth and Mars, and the forces of the planets acting on the Sun.
#
# You may consider the effect of the Earth on the Sun to be negligible, and it is very small, but it is not zero. Although we have assumed here that the Earth and Mars orbit around the center of the Sun, this is actually not true. If we look at only the Earth and the Sun, the two objects <b>both</b> orbit around their common center of mass. Remember that the center of mass for the Earth and Sun is defined as
#
# $$
#     {\vec r}_{CM} = \frac{M_{Sun} {\vec r}_{Sun} + m_{Earth} {\vec r}_{Earth}}{M_{sun} + m_{Earth}}
# $$
#
# **Problem:** Find the distance between the center of the Sun and the center of mass for the Earth-Sun system. The mass of the Earth is $5.97 \times 10^{24}$ kg, and the distance between their centers is about 149.6 million km; the mass of the Sun was given earlier in this notebook.
#
# **Problem:** The center of mass you found in the last problem is actually deep inside the Sun, which has a radius of $6.96 \times 10^5$ km. However, the Sun does orbit around this point over the course of one year! Figure out the tangential speed of the Sun's center as it orbits in a circular path around the Earth-Sun center of mass.
#
# One of the most successful methods of discovering exoplanets -- planets orbiting around other stars besides the Sun -- is called the **radial velocity** method, which detects this slight motion of the main star due to planets orbiting around it. In fact, the first detection of a planet around a Sun-like star used this method, and was the subject of the 2019 Nobel Prize in physics. The current state of the art is able to detect stellar motions of a few m/s, so an Earth-like body could not be detected by this method now. However, objects with much larger masses (such as the size of Jupiter) and closer to the star are readily observable.
#
# The other force not included in your simulation is the gravitational force between the Earth and Mars. Again, this will be a small effect, but an analogous force has been used to verify the existence of exoplanets. This is because the forces between planets give rise to small changes in the time each planet orbits the star. These **timing variations** have been seen in exoplanet systems where the planets are very close to the main star, and thus a lot closer to each other than the Earth and Mars ever come.
#
# ## Sending a rocket from the Earth to Mars
#
# Your next step will be to create a rocket that travels from the Earth to Mars along a Hohmann transfer orbit. Remember that this is an elliptical orbit between the two circular orbits of the planets. In other words, the closest point of the transfer orbit is at the same radius as the Earth, and the furthest point of the transfer orbit is the same radius as Mars.
#
# Here is some important information from the Lesson 32 worksheet you will need to complete this task:
#
# | Information                          | Value   |
# |--------------------------------------|---------|
# | Initial speed for transfer orbit     |32.7 km/s|
# |Transfer orbit time from Earth to Mars|    259 d|
#
# **Problem:** Convert the initial speed for the transfer orbit from Earth to Mars into PAU/Pyr.
#
# **Problem:** Convert the time to travel along the transfer orbit from Earth to Mars into Pyr.
#
# In order to simulate the motion of a rocket from the Earth to Mars, you will need to complete the following:
#
# 1. Create a sphere object called `rocket` in the place indicated in the cell above, with an initial position the same as the Earth's. You can give the rocket a trail (as the Earth and Mars have) so you can see its orbit more easily. The rocket should have the initial speed in PAU/Pyr you just calculated so that the rocket will travel in a transfer orbit towards the orbit of Mars. Remember that the initial *velocity* must be in the same direction that the Earth is traveling!
# 1. Update `rocket.velocity` and `rocket.pos` inside the `while` loop, just like is done for the Earth and Mars.
# 1. Change `MAX_TIME` so that it is the time (in Pyr) for the rocket to travel from the Earth to Mars.
# 1. If you wish, change `scene.camera.follow()` so that the simulation follows the motion of `rocket` instead of `Earth`.
# 1. If you do this correctly, the rocket should touch the orbit of Mars in the time (in Pyr) you figured out above at the time `MAX_TIME`. However, Mars will not be there at the same time!
# 1. You need to change the initial position of Mars by changing the angle `Q_Mars` so that the planet will be in the right location when the rocket reaches its orbital distance. **Hint:** The rocket arrives at Mars' orbit at $(-1, 0, 0)$, corresponding to the angle `Q = pi`. Thus, if you want Mars to be in the right place, you need to calculate the starting angle `Q_Mars` so that Mars is in the right spot 259 days later. You will need to use the orbital period of Mars in Pyr at the beginning of this notebook.
#
# Once all of this is done, when you run the cell you should see your rocket successfully meet Mars -- that's one small step for you, one giant leap for mankind!
#
# ## Challenge: Staying on Mars and coming home
#
# The mission is not complete until the astronauts leave Mars and return to Earth for their ticker tape parade in New York City. Remember that this involves a wait on Mars (calculated with the Lesson 32 worksheet) before the rocket starts along the return transfer orbit back to the Earth.
#
# So your challenge is to finish the mission by (1) having the rocket stay on Mars for the right amount of time, and then (2) return to Earth. One easy way to do this is to define a variable `WAIT_TIME` and then add two separate `while` loops, one for each phase of the mission, using this variable. See if you can get all of this to work, so the rocket executes the total Earth-Mars-Earth trip.
#
# # Summary
#
# After this lesson, you should be able to:
#
# * Calculate the orbital speed or period of a satellite moving in a circular orbit around a planet of given mass.
# * Find the relationship between the orbital period and semi-major axis for an elliptical orbit.
